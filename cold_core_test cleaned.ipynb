# %%
import iris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import iris.quickplot as qplt
import iris.plot as iplt
import datetime
import shutil
from six.moves import urllib
from pathlib import Path
import trackpy
from iris.time import PartialDateTime
import functions

import tobac #tobac package cloned from https://github.com/tobac-project/tobac.git

import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)
warnings.filterwarnings('ignore', category=RuntimeWarning, append=True)
warnings.filterwarnings('ignore', category=FutureWarning, append=True)
warnings.filterwarnings('ignore', category=pd.io.pytables.PerformanceWarning)

# %%
Track_multi = pd.read_hdf('Save/cold_core/Track_240_170_low.h5','table')
Track_single = pd.read_hdf('Save/Jan_2005/singleTb/Track_240.h5', 'table')

# %%
print(np.unique(Track_multi.cell.values).shape[0], '  unique cloud cells in month Jan 2005 when using multithreshold. Features:', Track_multi.shape[0])
print(np.unique(Track_single.cell.values).shape[0], '  unique cloud cells in month Jan 2005 when using single threshold. Features:', Track_single.shape[0])
# Out:
# 2   unique cloud cells in month Jan 2005 when using multithreshold. Features: 859
# 392   unique cloud cells in month Jan 2005 when using single threshold. Features: 9081

# %%
print(len(Track_multi['cell'].dropna().unique()))
print(len(Track_single['cell'].dropna().unique()))
# Out:
# 2
# 392

# %%
Track_multi
# Out:
#       frame  idx      hdim_1      hdim_2      num  threshold_value  feature  \
# 0         0    3  683.783509  672.445019  1673762              240        1
# 1         1    3  682.063623  673.062044  1683354              240        2
# 2         2    3  680.454574  674.059719  1692612              240        3
# 3         3    3  678.670430  675.502931  1694570              240        4
# 4         4    3  676.184119  677.627681  1699955              240        5
# ...     ...  ...         ...         ...      ...              ...      ...
# 1168    739    4  712.896637  603.545541  1596405              240     1169
# 1169    740    3  711.481042  600.949677  1594520              240     1170
# 1170    741    3  709.931744  599.095492  1593712              240     1171
# 1171    742    3  707.684162  598.550666  1593716              240     1172
# 1172    743    3  705.107529  599.293780  1589818              240     1173
#
#                      time              timestr   latitude  longitude  \
# 0     2005-01-01 00:30:00  2005-01-01 00:30:00 -12.346818 -57.805922
# 1     2005-01-01 01:30:00  2005-01-01 01:30:00 -12.416473 -57.780935
# 2     2005-01-01 02:30:00  2005-01-01 02:30:00 -12.481640 -57.740532
# 3     2005-01-01 03:30:00  2005-01-01 03:30:00 -12.553898 -57.682086
# 4     2005-01-01 04:30:00  2005-01-01 04:30:00 -12.654593 -57.596022
# ...                   ...                  ...        ...        ...
# 1168  2005-01-31 19:30:00  2005-01-31 19:30:00 -11.167737 -60.596346
# 1169  2005-01-31 20:30:00  2005-01-31 20:30:00 -11.225068 -60.701501
# 1170  2005-01-31 21:30:00  2005-01-31 21:30:00 -11.287816 -60.776589
# 1171  2005-01-31 22:30:00  2005-01-31 22:30:00 -11.378842 -60.798653
# 1172  2005-01-31 23:30:00  2005-01-31 23:30:00 -11.483196 -60.768559
#
#       forecast_reference_time  forecast_period  cell        time_cell
# 0                  302.194078       302.194078     1  0 days 00:00:00
# 1                  302.219065       302.219065     1  0 days 01:00:00
# 2                  302.259468       302.259468     1  0 days 02:00:00
# 3                  302.317914       302.317914     1  0 days 03:00:00
# 4                  302.403978       302.403978     1  0 days 04:00:00
# ...                       ...              ...   ...              ...
# 1168               299.403654       299.403654     1 30 days 19:00:00
# 1169               299.298499       299.298499     1 30 days 20:00:00
# 1170               299.223411       299.223411     1 30 days 21:00:00
# 1171               299.201347       299.201347     1 30 days 22:00:00
# 1172               299.231441       299.231441     1 30 days 23:00:00
#
# [1173 rows x 15 columns]

# %%
subset = Track_multi[Track_multi.cell>=0]
subset
# Out:
#       frame  idx      hdim_1      hdim_2      num  threshold_value  feature  \
# 0         0    3  683.783509  672.445019  1673762              240        1
# 1         1    3  682.063623  673.062044  1683354              240        2
# 2         2    3  680.454574  674.059719  1692612              240        3
# 3         3    3  678.670430  675.502931  1694570              240        4
# 4         4    3  676.184119  677.627681  1699955              240        5
# ...     ...  ...         ...         ...      ...              ...      ...
# 1168    739    4  712.896637  603.545541  1596405              240     1169
# 1169    740    3  711.481042  600.949677  1594520              240     1170
# 1170    741    3  709.931744  599.095492  1593712              240     1171
# 1171    742    3  707.684162  598.550666  1593716              240     1172
# 1172    743    3  705.107529  599.293780  1589818              240     1173
#
#                      time              timestr   latitude  longitude  \
# 0     2005-01-01 00:30:00  2005-01-01 00:30:00 -12.346818 -57.805922
# 1     2005-01-01 01:30:00  2005-01-01 01:30:00 -12.416473 -57.780935
# 2     2005-01-01 02:30:00  2005-01-01 02:30:00 -12.481640 -57.740532
# 3     2005-01-01 03:30:00  2005-01-01 03:30:00 -12.553898 -57.682086
# 4     2005-01-01 04:30:00  2005-01-01 04:30:00 -12.654593 -57.596022
# ...                   ...                  ...        ...        ...
# 1168  2005-01-31 19:30:00  2005-01-31 19:30:00 -11.167737 -60.596346
# 1169  2005-01-31 20:30:00  2005-01-31 20:30:00 -11.225068 -60.701501
# 1170  2005-01-31 21:30:00  2005-01-31 21:30:00 -11.287816 -60.776589
# 1171  2005-01-31 22:30:00  2005-01-31 22:30:00 -11.378842 -60.798653
# 1172  2005-01-31 23:30:00  2005-01-31 23:30:00 -11.483196 -60.768559
#
#       forecast_reference_time  forecast_period  cell        time_cell
# 0                  302.194078       302.194078     1  0 days 00:00:00
# 1                  302.219065       302.219065     1  0 days 01:00:00
# 2                  302.259468       302.259468     1  0 days 02:00:00
# 3                  302.317914       302.317914     1  0 days 03:00:00
# 4                  302.403978       302.403978     1  0 days 04:00:00
# ...                       ...              ...   ...              ...
# 1168               299.403654       299.403654     1 30 days 19:00:00
# 1169               299.298499       299.298499     1 30 days 20:00:00
# 1170               299.223411       299.223411     1 30 days 21:00:00
# 1171               299.201347       299.201347     1 30 days 22:00:00
# 1172               299.231441       299.231441     1 30 days 23:00:00
#
# [744 rows x 15 columns]

# %%
subset[subset.threshold_value == 170]
# Out:
# Empty DataFrame
# Columns: [frame, idx, hdim_1, hdim_2, num, threshold_value, feature, time, timestr, latitude, longitude, forecast_reference_time, forecast_period, cell, time_cell]
# Index: []

# %%
#cold core filter (removing any tracks that don't contain an area of 200K at some point over their lifetime)

for i in (subset['cell'].unique()): #for each unique cell value (each MCS)
    print(i)
    temp_sub = subset[subset.cell == i] #take a subset of rows for each MCS (take all the data of each MCS at each timestep)
    threshold_array = np.array(temp_sub.threshold_value.values) #create an array of the threshold that MCS reaches at each timestep
    for value in threshold_array: # for each value in the threshold array,
        if 170 not in threshold_array: #if the array does not include 200,
            subset = subset.drop(subset[subset.cell == i].index, axis=0) #drop all the rows corresponsing to that MCS cell (remove the MCS over all its timesteps)
            print('removed cell {}'.format(i))

subset
# Out:
# 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# removed cell 1
# Empty DataFrame
# Columns: [frame, idx, hdim_1, hdim_2, num, threshold_value, feature, time, timestr, latitude, longitude, forecast_reference_time, forecast_period, cell, time_cell]
# Index: []

# %%
subset[subset.cell == 870]
# Out:
# Empty DataFrame
# Columns: [frame, idx, hdim_1, hdim_2, num, threshold_value, feature, time, timestr, latitude, longitude, forecast_reference_time, forecast_period, cell, time_cell]
# Index: []

# %%
#print(len(subset['cell'].dropna().unique()))

print(np.unique(subset.cell.values).shape[0], '  unique cloud cells in month Jan 2005 when using 190K cold core filter. Features:', Track_multi.shape[0])
# Out:
# 0   unique cloud cells in month Jan 2005 when using 190K cold core filter. Features: 1173

# %%
import cartopy.crs as ccrs
axis_extent=[-80,-30,-35,12]

#loop for each timestep:
plt.figure()

fig_map,ax_map=plt.subplots(figsize=(30,28),subplot_kw={'projection': ccrs.PlateCarree()})
ax_map.set_extent([-85,-30,-40,10])
#tracks when no cold core filter: 
for cell in Track_single['cell'].dropna().unique():
    if cell == -1:
        continue
    Track_i_single_240 = Track_single[Track_single['cell'] == cell]
    plt.plot(Track_i_single_240['longitude'],Track_i_single_240['latitude'], '-',linewidth=5,color='grey',alpha=0.4)

#tracks when using 200K cold core filter
for cell in subset['cell'].dropna().unique():
    if cell == -1:
        continue
    Track_i_subset = subset[subset['cell'] == cell]
    plt.plot(Track_i_subset['longitude'],Track_i_subset['latitude'], '-',linewidth=5,color='orange')

#making legend labels for just 1 track in each filter:
cell_225 = 1
Track_single_240_1 = Track_single[Track_single['cell'] == cell_225]
plt.plot(Track_single_240_1['longitude'],Track_single_240_1['latitude'], '-', color='grey',alpha=0.4,label='240K single threshold = 392 tracks',linewidth=5)
Track_subset_1 = subset[subset['cell'] == cell_225]
plt.plot(Track_subset_1['longitude'],Track_subset_1['latitude'], '-', color='orange',label='With 200K cold core = 53 tracks',linewidth=5)

plt.xticks([-80,-70,-60,-50,-40,-30],fontsize=30)
plt.yticks([-40,-30,-20,-10,0,10],fontsize=30)
plt.gca().coastlines(linewidth=3)
plt.legend(loc='best',fontsize=30)
plt.xlabel('Lon $^\circ$E', fontsize=40)
plt.ylabel('Lat $^\circ$N', fontsize=40)

plt.savefig('Plot/cold_core/testing_Tb_filter_240_200.png')

# %%
tracks_225=pd.read_hdf('Save/cold_core/Track_coldcore_225.h5', 'table')
tracks_210=pd.read_hdf('Save/cold_core/Track_coldcore_210.h5', 'table')
tracks_200=pd.read_hdf('Save/cold_core/Track_coldcore_200.h5', 'table')
tracks_190=pd.read_hdf('Save/cold_core/Track_coldcore_190.h5', 'table')

# %%
dataframes= [tracks_225, tracks_210, tracks_200, tracks_190]

# %%
for df in dataframes:
    df.timestr = df.timestr.astype(str)
    df['datetime'] = pd.to_datetime(df.timestr.str.split(',\s*').str[0]) 
    set(df['datetime'])

# %%
#225
init_hours_225 = functions.get_mcs_init(tracks_225)
init_hours_225 = np.array(init_hours_225)
init_hours_225, bins = np.histogram(init_hours_225, bins = np.arange(0,25))

diss_hours_225 = functions.get_mcs_diss(tracks_225)
diss_hours_225 = np.array(diss_hours_225)
diss_hours_225, bins = np.histogram(diss_hours_225, bins = np.arange(0,25))

init_225 = init_hours_225/np.nansum(init_hours_225) * 100
diss_225 = diss_hours_225/np.nansum(diss_hours_225) * 100

#210
init_hours_210 = functions.get_mcs_init(tracks_210)
init_hours_210 = np.array(init_hours_210)
init_hours_210, bins = np.histogram(init_hours_210, bins = np.arange(0,25))

diss_hours_210 = functions.get_mcs_diss(tracks_210)
diss_hours_210 = np.array(diss_hours_210)
diss_hours_210, bins = np.histogram(diss_hours_210, bins = np.arange(0,25))

init_210 = init_hours_210/np.nansum(init_hours_210) * 100
diss_210 = diss_hours_210/np.nansum(diss_hours_210) * 100

#200
init_hours_200 = functions.get_mcs_init(tracks_200)
init_hours_200 = np.array(init_hours_200)
init_hours_200, bins = np.histogram(init_hours_200, bins = np.arange(0,25))

diss_hours_200 = functions.get_mcs_diss(tracks_200)
diss_hours_200 = np.array(diss_hours_200)
diss_hours_200, bins = np.histogram(diss_hours_200, bins = np.arange(0,25))

init_200 = init_hours_200/np.nansum(init_hours_200) * 100
diss_200 = diss_hours_200/np.nansum(diss_hours_200) * 100

#190
init_hours_190 = functions.get_mcs_init(tracks_190)
init_hours_190 = np.array(init_hours_190)
init_hours_190, bins = np.histogram(init_hours_190, bins = np.arange(0,25))

diss_hours_190 = functions.get_mcs_diss(tracks_190)
diss_hours_190 = np.array(diss_hours_190)
diss_hours_190, bins = np.histogram(diss_hours_190, bins = np.arange(0,25))

init_190 = init_hours_190/np.nansum(init_hours_190) * 100
diss_190 = diss_hours_190/np.nansum(diss_hours_190) * 100

# %%
#plot of initiation time of MCSs 
import seaborn as sns 
sns.set()

plt.figure(figsize=(26,18))
f= 30
lf= 30
l=32

ax1 = plt.subplot(2, 2, 1) 
ax1.set_title('a) 225K cold core ', loc='left', fontsize= 35 )
ax1.plot(np.arange(0,24), init_225, label = 'initiation ', color= 'darkblue', linewidth = 3)
ax1.plot(np.arange(0,24), diss_225, label = 'dissipation ', color= 'darkblue', linewidth = 3, linestyle = 'dotted')
ax1.legend(fontsize=lf)

a= np.arange(21,24,2)
b= np.arange(1,20,2)
localtime= np.append(a, b)

labels=localtime.astype(str)
ax1.set_yticks(np.arange(2,14,2))
ax1.set_xticks(np.arange(0,23)[::2])
ax1.set_yticklabels(ax1.get_yticks(),fontsize=f)
ax1.set_xticklabels(labels,fontsize= f)
ax1.set_xlim(-0.5,22.5)
ax1.set_xlabel('Local time (UTC-3)', fontsize= l)
ax1.set_ylabel('Frequency [%]', fontsize= l)

labels=localtime.astype(str)
ax2 = plt.subplot(2, 2, 2) 
ax2.set_title('b) 210K cold core ', loc='left', fontsize= 35 )
ax2.plot(np.arange(0,24), init_210, label = 'initiation ', color= 'crimson', linewidth = 3)
ax2.plot(np.arange(0,24), diss_210, label = 'dissipation ', color= 'crimson', linewidth = 3, linestyle = 'dotted')
ax2.legend(fontsize=lf)
ax2.set_yticks(np.arange(2,14,2))
ax2.set_xticks(np.arange(0,23)[::2])
ax2.set_xticklabels(labels,fontsize= f)
ax2.set_xlim(-0.5,22.5)
ax2.set_yticklabels(ax2.get_yticks(),fontsize=f)
ax2.set_xlabel('Local time (UTC-3)', fontsize= l)
ax2.set_ylabel('Frequency [%]', fontsize= l)

ax3 = plt.subplot(2, 2, 3) 
ax3.set_title('c) 200K cold core ', loc='left', fontsize= 35 )
ax3.plot(np.arange(0,24), init_200, label = 'initiation ', color= 'teal', linewidth = 3)
ax3.plot(np.arange(0,24), diss_200, label = 'dissipation ', color= 'teal', linewidth = 3, linestyle = 'dotted')
ax3.legend(fontsize=lf)
ax3.set_yticks(np.arange(2,14,2))
ax3.set_xticks(np.arange(0,23)[::2])
ax3.set_yticklabels(ax3.get_yticks(),fontsize=f)
ax3.set_xticklabels(labels,fontsize= f)
ax3.set_xlim(-0.5,22.5)
ax3.set_xlabel('Local time (UTC-3)', fontsize= l)
ax3.set_ylabel('Frequency [%]', fontsize= l)

ax4 = plt.subplot(2, 2, 4) 
ax4.set_title('d) 190K cold core ', loc='left', fontsize= 35 )
ax4.plot(np.arange(0,24), init_190, label = 'initiation ', color= 'orange', linewidth = 3)
ax4.plot(np.arange(0,24), diss_190, label = 'dissipation ', color= 'orange', linewidth = 3, linestyle = 'dotted')
ax4.legend(fontsize=lf)
ax4.set_yticks(np.arange(0,35,5))
ax4.set_xticks(np.arange(0,23)[::2])
ax4.set_yticklabels(ax4.get_yticks(),fontsize=f)
ax4.set_xticklabels(labels,fontsize= f)
ax4.set_xlim(-0.5,22.5)
ax4.set_xlabel('Local time (UTC-3)', fontsize= l)
ax4.set_ylabel('Frequency [%]', fontsize= l)

plt.tight_layout()

plt.savefig('Plot/cold_core/init_diss.png')

# %%
init_lats_225, init_lons_225, diss_lats_225, diss_lons_225 = functions.get_init(tracks_225)
init_lats_210, init_lons_210, diss_lats_210, diss_lons_210 = functions.get_init(tracks_210)
init_lats_200, init_lons_200, diss_lats_200, diss_lons_200 = functions.get_init(tracks_200)
init_lats_190, init_lons_190, diss_lats_190, diss_lons_190 = functions.get_init(tracks_190)

# %%
import cartopy.crs as ccrs

fig = plt.figure(figsize=(25,15))
xlabels=[-90,-70,-50,-30]
ylabels= [-40,-30,-20,-10,0,10]
# markersize 
s = 100
#fontsize
f=40

plt.subplots_adjust(wspace=0,hspace=0)
# Locations of initiation and dissipation of MCSs 
ax1 = plt.subplot(2, 2, 1, projection=ccrs.PlateCarree())
ax1.set_title('a) 225K cold core', loc='left', fontsize= f )
ax1.scatter(init_lons_225, init_lats_225,  color='darkblue',marker='o', s = s, transform=ccrs.PlateCarree(),label= 'initiation')
ax1.scatter(diss_lons_225, diss_lats_225,  color='blue',marker='o', s = s/2, transform=ccrs.PlateCarree(),label= 'dissipation')
ax1.coastlines(linewidth=2)
ax1.legend(fontsize= 30)
ax1.set_xticks([-90,-80, -70, -60, -50, -40, -30])
ax1.set_yticks([-40,-30,-20,-10,0,10])
ax1.set_xticklabels(ax1.get_xticks().astype(int),fontsize=25)
ax1.set_yticklabels(ax1.get_yticks().astype(int),fontsize=25)
ax1.set_xlabel('Lon $^\circ$E',  fontsize=30)
ax1.set_ylabel('Lat $^\circ$N',  fontsize=30)

ax2 = plt.subplot(2, 2, 2, projection=ccrs.PlateCarree())
ax2.set_title('b) 210K cold core ', loc='left', fontsize= f )
ax2.scatter(init_lons_210, init_lats_210,  color='crimson',marker='o', s = s, transform=ccrs.PlateCarree(),label= 'initiation')
ax2.scatter(diss_lons_210, diss_lats_210,  color='pink',marker='o', s = s/2, transform=ccrs.PlateCarree(),label= 'dissipation')
ax2.coastlines(linewidth=2)
ax2.legend(fontsize= 30)
ax2.set_xticks([-90,-80, -70, -60, -50, -40, -30])
ax2.set_yticks([-40,-30,-20,-10,0,10])
ax2.set_xticklabels(ax2.get_xticks().astype(int),fontsize=25)
ax2.set_yticklabels(ax2.get_yticks().astype(int),fontsize=25)
ax2.set_xlabel('Lon $^\circ$E',  fontsize=30)
ax2.set_ylabel('Lat $^\circ$N',  fontsize=30)

ax3 = plt.subplot(2, 2, 3, projection=ccrs.PlateCarree())
ax3.set_title('c) 200K cold core ', loc='left', fontsize= f )
ax3.scatter(init_lons_200, init_lats_200,  color='teal',marker='o', s = s, transform=ccrs.PlateCarree(),label= 'initiation')
ax3.scatter(diss_lons_200, diss_lats_200,  color='skyblue',marker='o', s = s/2, transform=ccrs.PlateCarree(),label= 'dissipation')
ax3.coastlines(linewidth=2)
ax3.legend(fontsize= 30)
ax3.set_xticks([-90,-80, -70, -60, -50, -40, -30])
ax3.set_yticks([-40,-30,-20,-10,0,10])
ax3.set_xticklabels(ax3.get_xticks().astype(int),fontsize=25)
ax3.set_yticklabels(ax3.get_yticks().astype(int),fontsize=25)
ax3.set_xlabel('Lon $^\circ$E',  fontsize=30)
ax3.set_ylabel('Lat $^\circ$N',  fontsize=30)

ax4 = plt.subplot(2, 2, 4, projection=ccrs.PlateCarree())
ax4.set_title('d) 190K cold core ', loc='left', fontsize= f )
ax4.scatter(init_lons_190, init_lats_190,  color='orange',marker='o', s = s, transform=ccrs.PlateCarree(),label= 'initiation')
ax4.scatter(diss_lons_190, diss_lats_190,  color='gold',marker='o', s = s/2, transform=ccrs.PlateCarree(),label= 'dissipation')
ax4.legend(fontsize= 30)
ax4.coastlines(linewidth=2)
ax4.set_xticks([-90,-80, -70, -60, -50, -40, -30])
ax4.set_yticks([-40,-30,-20,-10,0,10])
ax4.set_xticklabels(ax4.get_xticks().astype(int),fontsize=25)
ax4.set_yticklabels(ax4.get_yticks().astype(int),fontsize=25)
ax4.set_xlabel('Lon $^\circ$E',  fontsize=30)
ax4.set_ylabel('Lat $^\circ$N',  fontsize=30)


fig.tight_layout()

plt.savefig('Plot/cold_core/init_diss_loc.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test cleaned.ipynb Cell 18 in 1
#      <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X42sZmlsZQ%3D%3D?line=12'>13</a> ax1 = plt.subplot(2, 2, 1, projection=ccrs.PlateCarree())
#      <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X42sZmlsZQ%3D%3D?line=13'>14</a> ax1.set_title('a) 225K cold core', loc='left', fontsize= f )
# ---> <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X42sZmlsZQ%3D%3D?line=14'>15</a> ax1.scatter(init_lons_225, init_lats_225,  color='darkblue',marker='o', s = s, transform=ccrs.PlateCarree(),label= 'initiation')
#      <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X42sZmlsZQ%3D%3D?line=15'>16</a> ax1.scatter(diss_lons_225, diss_lats_225,  color='blue',marker='o', s = s/2, transform=ccrs.PlateCarree(),label= 'dissipation')
#      <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X42sZmlsZQ%3D%3D?line=16'>17</a> ax1.coastlines(linewidth=2)
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:318, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     313     raise ValueError(f'Invalid transform: Spherical {func.__name__} '
#     314                      'is not supported - consider using '
#     315                      'PlateCarree/RotatedPole.')
#     317 kwargs['transform'] = transform
# --> 318 return func(self, *args, **kwargs)
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1700, in GeoAxes.scatter(self, *args, **kwargs)
#    1692 if (isinstance(kwargs['transform'],
#    1693                InterProjectionTransform) and
#    1694         kwargs['transform'].source_projection.is_geodetic()):
#    1695     raise ValueError('Cartopy cannot currently do spherical '
#    1696                      'scatter. The source CRS cannot be a '
#    1697                      'geodetic, consider using the cyllindrical form '
#    1698                      '(PlateCarree or RotatedPole).')
# -> 1700 result = super().scatter(*args, **kwargs)
#    1701 self.autoscale_view()
#    1702 return result
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4647, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4644     if self._ymargin < 0.05 and x.size > 0:
#    4645         self.set_ymargin(0.05)
# -> 4647 self.add_collection(collection)
#    4648 self._request_autoscale_view()
#    4650 return collection
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/matplotlib/axes/_base.py:2300, in _AxesBase.add_collection(self, collection, autolim)
#    2296 if autolim:
#    2297     # Make sure viewLim is not stale (mostly to match
#    2298     # pre-lazy-autoscale behavior, which is not really better).
#    2299     self._unstale_viewLim()
# -> 2300     datalim = collection.get_datalim(self.transData)
#    2301     points = datalim.get_points()
#    2302     if not np.isinf(datalim.minpos).all():
#    2303         # By definition, if minpos (minimum positive value) is set
#    2304         # (i.e., non-inf), then min(points) <= minpos <= max(points),
#    2305         # and minpos would be superfluous. However, we add minpos to
#    2306         # the call so that self.dataLim will update its own minpos.
#    2307         # This ensures that log scales see the correct minimum.
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/matplotlib/collections.py:294, in Collection.get_datalim(self, transData)
#     287 # NOTE: None is the default case where no offsets were passed in
#     288 if self._offsets is not None:
#     289     # this is for collections that have their paths (shapes)
#     290     # in physical, axes-relative, or figure-relative units
#     291     # (i.e. like scatter). We can't uniquely set limits based on
#     292     # those shapes, so we just set the limits based on their
#     293     # location.
# --> 294     offsets = (offset_trf - transData).transform(offsets)
#     295     # note A-B means A B^{-1}
#     296     offsets = np.ma.masked_invalid(offsets)
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/matplotlib/transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:134, in InterProjectionTransform.transform_non_affine(self, xy)
#     132 prj = self.target_projection
#     133 if isinstance(xy, np.ndarray):
# --> 134     return prj.transform_points(self.source_projection,
#     135                                 xy[:, 0], xy[:, 1])[:, 0:2]
#     136 else:
#     137     x, y = xy
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/cartopy/crs.py:408, in CRS.transform_points(self, src_crs, x, y, z, trap)
#     405     x[to_180] = (((x[to_180] + 180) % 360) - 180)
#     406 try:
#     407     result[:, 0], result[:, 1], result[:, 2] = \
# --> 408         _safe_pj_transform(src_crs, self, x, y, z, trap=trap)
#     409 except ProjError as err:
#     410     msg = str(err).lower()
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/cartopy/crs.py:49, in _safe_pj_transform(src_crs, tgt_crs, x, y, z, trap)
#      48 def _safe_pj_transform(src_crs, tgt_crs, x, y, z=None, trap=True):
# ---> 49     transformer = _get_transformer_from_crs(src_crs, tgt_crs)
#      51     # if a projection is essentially 2d there
#      52     # should be no harm in setting its z to 0
#      53     if z is None:
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/cartopy/crs.py:45, in _get_transformer_from_crs(src_crs, tgt_crs)
#      43 @lru_cache
#      44 def _get_transformer_from_crs(src_crs, tgt_crs):
# ---> 45     return Transformer.from_crs(src_crs, tgt_crs, always_xy=True)
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/pyproj/transformer.py:598, in Transformer.from_crs(crs_from, crs_to, always_xy, area_of_interest, authority, accuracy, allow_ballpark, force_over)
#     539 @staticmethod
#     540 def from_crs(
#     541     crs_from: Any,
#    (...)
#     548     force_over: bool = False,
#     549 ) -> "Transformer":
#     550     """Make a Transformer from a :obj:`pyproj.crs.CRS` or input used to create one.
#     551
#     552     See:
#    (...)
#     596
#     597     """
# --> 598     return Transformer(
#     599         TransformerFromCRS(
#     600             cstrencode(CRS.from_user_input(crs_from).srs),
#     601             cstrencode(CRS.from_user_input(crs_to).srs),
#     602             always_xy=always_xy,
#     603             area_of_interest=area_of_interest,
#     604             authority=authority,
#     605             accuracy=accuracy if accuracy is None else str(accuracy),
#     606             allow_ballpark=allow_ballpark,
#     607             force_over=force_over,
#     608         )
#     609     )
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/pyproj/transformer.py:326, in Transformer.__init__(self, transformer_maker)
#     320     raise ProjError(
#     321         "Transformer must be initialized using: "
#     322         "'from_crs', 'from_pipeline', or 'from_proj'."
#     323     )
#     325 self._local = TransformerLocal()
# --> 326 self._local.transformer = transformer_maker()
#     327 self._transformer_maker = transformer_maker
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/pyproj/transformer.py:102, in TransformerFromCRS.__call__(self)
#      96 def __call__(self) -> _Transformer:
#      97     """
#      98     Returns
#      99     -------
#     100     _Transformer
#     101     """
# --> 102     return _Transformer.from_crs(
#     103         self.crs_from,
#     104         self.crs_to,
#     105         always_xy=self.always_xy,
#     106         area_of_interest=self.area_of_interest,
#     107         authority=self.authority,
#     108         accuracy=self.accuracy,
#     109         allow_ballpark=self.allow_ballpark,
#     110         force_over=self.force_over,
#     111     )
#
# File pyproj/_transformer.pyx:544, in pyproj._transformer._Transformer.from_crs()
#
# File pyproj/_transformer.pyx:614, in pyproj._transformer._Transformer._init_from_crs()
#
# File pyproj/_transformer.pyx:328, in pyproj._transformer._Transformer._initialize_from_projobj()
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/pyproj/exceptions.py:19, in ProjError.clear()
#      16         ProjError.clear()
#      17     super().__init__(error_message)
# ---> 19 @staticmethod
#      20 def clear() -> None:
#      21     """
#      22     This will clear the internal PROJ erro message.
#      23     """
#      24     ProjError.internal_proj_error = None
#
# KeyboardInterrupt:

# %%
area_225=functions.get_area(tracks_225)
area_210=functions.get_area(tracks_210)
area_200=functions.get_area(tracks_200)
area_190=functions.get_area(tracks_190)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test cleaned.ipynb Cell 19 in 1
# ----> <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> area_225=functions.get_area(tracks_225)
#       <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> area_210=functions.get_area(tracks_210)
#       <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> area_200=functions.get_area(tracks_200)
#
# File /net/data/users/hgilmour/tracking/code/tobac_sensitivity/functions.py:576, in get_area(mcstracks)
#     574 a= []
#     575 for cell in np.unique(mcstracks.cell.values):
# --> 576     gcells= np.mean(np.array(mcstracks[mcstracks.cell== cell].num.values))
#     577     area=gcells*(4.5**2)
#     578     a.append(area)
#
# File <__array_function__ internals>:180, in mean(*args, **kwargs)
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432, in mean(a, axis, dtype, out, keepdims, where)
#    3429     else:
#    3430         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3432 return _methods._mean(a, axis=axis, dtype=dtype,
#    3433                       out=out, **kwargs)
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/numpy/core/_methods.py:168, in _mean(a, axis, dtype, out, keepdims, where)
#     164 arr = asanyarray(a)
#     166 is_float16_result = False
# --> 168 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     169 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     170     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File ~/.conda/envs/myclone/lib/python3.9/site-packages/numpy/core/_methods.py:66, in _count_reduce_items(arr, axis, keepdims, where)
#      63         return umr_all(a, axis, dtype, out, keepdims)
#      64     return umr_all(a, axis, dtype, out, keepdims, where=where)
# ---> 66 def _count_reduce_items(arr, axis, keepdims=False, where=True):
#      67     # fast-path for the default case
#      68     if where is True:
#      69         # no boolean mask given, calculate items according to axis
#      70         if axis is None:
#
# KeyboardInterrupt:

# %%
#plot of initiation time of MCSs 
import seaborn as sns 
sns.set(font_scale=2)

fig = plt.figure(figsize=(26,15))
t = 40
f= 35
n = 25
lf= 15


ax1=plt.subplot(2,2,1)
ax1.set_title('a) 225K cold core', loc='left', fontsize= t )
ax1.hist(area_225,bins=[40000,80000,120000,160000,200000,240000,280000,320000,360000,400000,440000],width=35000,color= 'darkblue',align='mid')
ax1.set_xlabel('MCS area (km$^{2}$)', fontsize= f)
ax1.set_xticks([60000,100000,140000,180000,220000,260000,300000,340000,380000,420000,460000])
ax1.set_yticks([0,20,40,60,80,100])
ax1.set_yticklabels(ax1.get_yticks(),fontsize=n)
ax1.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax1.xaxis.get_offset_text().set_fontsize(25)
ax1.set_ylabel('Count',fontsize=f)

ax2=plt.subplot(2,2,2)
ax2.set_title('b) 210K cold core', loc='left', fontsize= t )
ax2.hist(area_210,bins=[40000,80000,120000,160000,200000,240000,280000,320000,360000,400000,440000],width=35000,color= 'crimson',align='mid')
ax2.set_xlabel('MCS area (km$^{2}$)', fontsize= f)
ax2.set_xticks([60000,100000,140000,180000,220000,260000,300000,340000,380000,420000,460000])
ax2.set_yticks([0,20,40,60,80,100])
ax2.set_yticklabels(ax1.get_yticks(),fontsize=n)
ax2.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax2.xaxis.get_offset_text().set_fontsize(25)
ax2.set_ylabel('Count',fontsize=f)

ax3=plt.subplot(2,2,3)
ax3.set_title('c) 200K cold core ', loc='left', fontsize= t)
ax3.hist(area_200,bins=[40000,80000,120000,160000,200000,240000,280000,320000,360000,400000,440000],width=35000,color= 'teal',align='mid')
ax3.set_xlabel('MCS area (km$^{2}$)', fontsize= f)
ax3.set_xticks([60000,100000,140000,180000,220000,260000,300000,340000,380000,420000,460000])
ax3.set_yticks([0,20,40,60,80,100])
ax3.set_yticklabels(ax1.get_yticks(),fontsize=n)
ax3.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax3.xaxis.get_offset_text().set_fontsize(25)
ax3.set_ylabel('Count',fontsize=f)

ax4=plt.subplot(2,2,4)
ax4.set_title('d) 190K cold core ', loc='left', fontsize= t )
ax4.hist(area_190,bins=[40000,80000,120000,160000,200000,240000,280000,320000,360000,400000,440000],width=35000,color= 'orange',align='mid')
ax4.set_xlabel('MCS area (km$^{2}$)', fontsize= f)
ax4.set_xticks([60000,100000,140000,180000,220000,260000,300000,340000,380000,420000,460000])
ax4.set_yticks([0,20,40,60,80,100])
ax4.set_yticklabels(ax1.get_yticks(),fontsize=n)
ax4.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
ax4.xaxis.get_offset_text().set_fontsize(25)
ax4.set_ylabel('Count',fontsize=f)

fig.tight_layout()
plt.savefig('Plot/cold_core/area.png')

# %% [markdown]
# *comparing the feature points when using a 200K cold core with the masks/tracks of single 240K tb threshold*

# %%
import cartopy.crs as ccrs
axis_extent=[-80,-30,-35,12]

#loop for each timestep:
plt.figure()

fig_map,ax_map=plt.subplots(figsize=(30,28),subplot_kw={'projection': ccrs.PlateCarree()})
ax_map.set_extent([-85,-30,-40,10])
#tracks when using 225K cold core filter
for cell in Track_single_240['cell'].dropna().unique():
    if cell == -1:
        continue
    Track_i_single_240 = Track_single_240[Track_single_240['cell'] == cell]
    plt.plot(Track_i_single_240['longitude'],Track_i_single_240['latitude'], '-',linewidth=5,color='purple',alpha=0.4)


plt.scatter(x=subset_2['longitude'],y=subset_2['latitude'],c='k',marker='x',s=200,linewidth=4,zorder=5)


for cell in subset_2['cell'].dropna().unique():
    if cell == -1:
        continue
    Track_i_subset_2 = subset_2[subset_2['cell'] == cell]
    plt.plot(Track_i_subset_2['longitude'],Track_i_subset_2['latitude'], '-',linewidth=5,color='teal')


#making legend labels for just 1 track in each filter:
cell_225 = 30
Track_single_240_1 = Track_single_240[Track_single_240['cell'] == cell_225]
plt.plot(Track_single_240_1['longitude'],Track_single_240_1['latitude'], '-', color='purple',alpha=0.4,label='240K single threshold = 392 tracks',linewidth=5)


plt.xticks([-80,-70,-60,-50,-40,-30],fontsize=30)
plt.yticks([-40,-30,-20,-10,0,10],fontsize=30)
plt.gca().coastlines(linewidth=3)
plt.legend(loc='best',fontsize=30)
plt.xlabel('Lon $^\circ$E', fontsize=40)
plt.ylabel('Lat $^\circ$N', fontsize=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test cleaned.ipynb Cell 23 in 1
#       <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X50sZmlsZQ%3D%3D?line=7'>8</a> ax_map.set_extent([-85,-30,-40,10])
#       <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X50sZmlsZQ%3D%3D?line=8'>9</a> #tracks when using 225K cold core filter
# ---> <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X50sZmlsZQ%3D%3D?line=9'>10</a> for cell in Track_single_240['cell'].dropna().unique():
#      <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X50sZmlsZQ%3D%3D?line=10'>11</a>     if cell == -1:
#      <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X50sZmlsZQ%3D%3D?line=11'>12</a>         continue
#
# NameError: name 'Track_single_240' is not defined

# %%
print(len(Track_single_240['cell'].unique()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test cleaned.ipynb Cell 23 in 1
# ----> <a href='vscode-notebook-cell:/data/users/hgilmour/tracking/code/tobac_sensitivity/cold_core_test%20cleaned.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> print(len(Track_single_240['cell'].unique()))
#
# NameError: name 'Track_single_240' is not defined
